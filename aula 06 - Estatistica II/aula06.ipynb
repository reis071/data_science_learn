# %% [markdown]
# # Estatistica II

# %% [markdown]
# ## Oque É Probabilidade?
#
# Probabilidade é a área da matemática que estuda a chance de um evento acontecer. Imagine que você joga uma moeda para o alto. Como a moeda tem dois lados, cara ou coroa, a probabilidade de cair um desses lados é de 50%.

# %% [markdown]
# ### Como Calcular a Probabilidade

# %% [markdown]
# $$
# P(E) = \frac{\text{Número de resultados favoráveis}}{\text{Número total de resultados possíveis}}
# $$
#
# 𝑃(𝐸) é a probabilidade do evento 𝐸 acontecer.
#
# Número de resultados favoráveis é o número de maneiras que o evento pode acontecer.
#
# Número total de resultados possíveis é o número total de todos os eventos possíveis.

# %% [markdown]
# ### Exemplo

# %% [markdown]
# Suponha que você tem um dado comum com 6 faces numeradas de 1 a 6. Qual é a probabilidade de você tirar um número 4?
#
# Número de resultados favoráveis: 1 (apenas o número 4)
# Número total de resultados possíveis: 6 (já que o dado tem 6 faces)

# %% [markdown]
# $$
# P(4) = \frac{1}{6} \approx 0.167
# $$
#
# Portanto, a probabilidade de tirar o número 4 é cerca de 16,7%.

# %%
import pandas as pd

# Suponha que você tem o seguinte DataFrame com os resultados dos lançamentos de um dado
data = {'Lancamento': [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 6, 6]}
df = pd.DataFrame(data)

# Calcular a probabilidade de tirar um número 6
total_lancamentos = len(df)
resultados_favoraveis = df[df['Lancamento'] == 6].count()

probabilidade_6 = resultados_favoraveis / total_lancamentos

print(f"A probabilidade de tirar um número 6 é: {probabilidade_6[0]:.2f}")

# %% [markdown]
# ### Espaço Amostral

# %% [markdown]
# O espaço amostral é o conjunto de todos os resultados possíveis de um experimento aleatório. Em outras palavras, é como uma lista que contém todas as coisas que podem acontecer quando você realiza o experimento.

# %% [markdown]
# ### Experimento Aleatório

# %% [markdown]
# Um experimento aleatório é qualquer ação ou processo que tem um resultado incerto, ou seja, você não pode prever exatamente o que vai acontecer. Por exemplo, jogar uma moeda, lançar um dado, ou escolher uma carta de um baralho são todos exemplos de experimentos aleatórios.

# %% [markdown]
# ## Graficos

# %% [markdown]
# ### Matplotlib
#
#
# Matplotlib é uma biblioteca em Python usada para criar visualizações gráficas. É uma das bibliotecas mais populares para gerar gráficos, e é amplamente utilizada em ciência de dados, aprendizado de máquina e análise de dados. O Matplotlib permite criar uma grande variedade de gráficos, como gráficos de linha, de barras, de dispersão, histogramas, entre outro

# %% [markdown]
# ### O que são Gráficos?
#
# Gráficos são representações visuais de dados que ajudam a entender, analisar e comunicar informações de forma clara e eficiente. Ao invés de olhar para uma tabela cheia de números, um gráfico pode tornar a informação mais acessível, mostrando padrões, tendências ou comparações de forma imediata.

# %% [markdown]
# ### Por que Usar Gráficos?
#
# **Facilitam a compreensão**: Visualmente, é mais fácil perceber tendências e padrões.
#
# **Resumem informações complexas**: Dados extensos podem ser resumidos em uma imagem simples.
#
# **Ajudam na tomada de decisões**: Visualizar dados ajuda a tomar decisões informadas rapidamente.

# %% [markdown]
# ### Tipos de Gráficos

# %% [markdown]
# #### Histograma
#
# Um histograma é um tipo de gráfico que mostra a distribuição de uma variável contínua. Ele agrupa os dados em intervalos (bins) e representa a frequência ou a contagem de valores que caem em cada intervalo. Diferente do gráfico de barras, que compara categorias, o histograma é usado para visualizar a distribuição de dados e identificar padrões, como a forma (normal, assimétrica, etc.), a dispersão, e a presença de outliers.

# %% [markdown]
# #### Como Funciona?
#
# **Eixos**: No histograma, o eixo horizontal (x) representa os intervalos de valores, e o eixo vertical (y) mostra a frequência ou a contagem de valores dentro de cada intervalo.
#
# **Barras**: Cada barra no histograma representa o número de ocorrências (frequência) de dados dentro de um intervalo específico

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados de exemplo: idades de um grupo de pessoas
idades = [22, 25, 28, 22, 30, 32, 35, 40, 28, 30, 32, 35, 40, 45, 50, 52, 55, 60, 22, 28, 35, 40, 50, 60]

# Criar um DataFrame
df = pd.DataFrame(idades, columns=['Idade'])

# Criar o histograma
df['Idade'].plot(kind='hist', bins=5, color='skyblue', edgecolor='black')

# Adicionar título e rótulos
plt.title('Distribuição de Idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### Gráfico De Barras
#
# Um gráfico de barras é uma forma visual de comparar valores entre diferentes categorias ou grupos. Nele, cada barra representa uma categoria, e a altura (ou comprimento) da barra indica o valor associado a essa categoria. É especialmente útil quando você deseja comparar diferentes itens ou ver mudanças em uma única variável ao longo do tempo.

# %% [markdown]
# #### Como Funciona?
#
# **Eixos**: O eixo horizontal (x) geralmente representa as categorias, e o eixo vertical (y) mostra os valores (como contagem, média, porcentagem, etc.).
#
# **Barras**: Cada barra corresponde a uma categoria. Quanto maior a barra, maior o valor que ela representa.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados de exemplo: Vendas de diferentes produtos
dados = {
    'Produto': ['Produto A', 'Produto B', 'Produto C', 'Produto D'],
    'Vendas': [250, 150, 300, 200]
}

# Criar um DataFrame
df = pd.DataFrame(dados)

# Criar o gráfico de barras
df.plot(kind='bar', x='Produto', y='Vendas', color='lightgreen', edgecolor='black')

# Adicionar título e rótulos aos eixos
plt.title('Vendas por Produto')
plt.xlabel('Produto')
plt.ylabel('Vendas')
plt.grid(True, linestyle='--', alpha=0.6)

# Exibir o gráfico
plt.show()

# %% [markdown]
# ### Gráfico De Pizza
#
# O gráfico de pizza (ou gráfico de setores) é uma representação visual usada para mostrar a proporção de partes em relação ao todo. Cada "fatia" da pizza representa uma categoria, e o tamanho da fatia indica a porcentagem ou proporção daquela categoria em relação ao total. Este tipo de gráfico é útil para mostrar a distribuição de um conjunto de dados de maneira intuitiva.

# %% [markdown]
# #### Como Funciona?
#
# **Fatia**: Cada fatia representa uma categoria e seu tamanho corresponde à proporção daquela categoria no conjunto de dados.
#
# **Total**: O gráfico de pizza sempre representa 100% do total, e as fatias somadas devem dar esse valor.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados de exemplo: Participação de mercado de diferentes empresas
dados = {
    'Empresa': ['Empresa A', 'Empresa B', 'Empresa C', 'Empresa D'],
    'Participação (%)': [35, 25, 20, 20]
}

# Criar um DataFrame
df = pd.DataFrame(dados)

# Criar o gráfico de pizza
plt.pie(df['Participação (%)'], labels=df['Empresa'], autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])

# Adicionar título
plt.title('Participação de Mercado por Empresa')

# Exibir o gráfico
plt.show()

# %% [markdown]
# ### Intervalo Interquartílico (IQR)
#
# O Intervalo Interquartílico (IQR) é uma medida de dispersão que descreve a amplitude do intervalo central de um conjunto de dados, eliminando a influência de valores extremos ou outliers. Ele é definido como a diferença entre o terceiro quartil (Q3) e o primeiro quartil (Q1) de um conjunto de dados.

# %% [markdown]
# #### Quartis
#
# Q1 (Primeiro Quartil): Representa o valor abaixo do qual se encontram 25% dos dados. É também conhecido como o 25º percentil.
#
# Q2 (Mediana): O segundo quartil, ou mediana, divide o conjunto de dados ao meio, com 50% dos dados abaixo dele.
#
# Q3 (Terceiro Quartil): Representa o valor abaixo do qual se encontram 75% dos dados. É também conhecido como o 75º percentil.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados de exemplo: notas de um grupo de estudantes
notas = [55, 70, 75, 80, 85, 90, 95, 100, 105, 110]

# Criar um DataFrame
df = pd.DataFrame(notas, columns=['Notas'])

# Criar o boxplot
plt.figure(figsize=(8, 6))
boxplot = df.boxplot(column=['Notas'], grid=True, patch_artist=True, boxprops=dict(facecolor='lightblue'))

# Calcular Q1, Q2 (mediana) e Q3
Q1 = df['Notas'].quantile(0.25)
Q2 = df['Notas'].median()
Q3 = df['Notas'].quantile(0.75)

# Adicionar linhas horizontais para os quartis
plt.axhline(y=Q1, color='orange', linestyle='--', linewidth=2, label='Q1 (1º Quartil)')
plt.axhline(y=Q2, color='green', linestyle='--', linewidth=2, label='Q2 (Mediana)')
plt.axhline(y=Q3, color='red', linestyle='--', linewidth=2, label='Q3 (3º Quartil)')

# Adicionar título e rótulos aos eixos
plt.title('Boxplot das Notas dos Estudantes com Quartis Sinalizados')
plt.ylabel('Notas')

# Adicionar legenda para identificar os quartis
plt.legend()

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## Distribuição Normal
#
# A distribuição normal, também conhecida como distribuição Gaussiana ou curva de sino, é uma das distribuições de probabilidade mais importantes em estatística. Ela descreve como os valores de uma variável se distribuem de maneira simétrica em torno da média. Muitos fenômenos naturais, como altura, peso, e notas de testes, tendem a seguir uma distribuição normal.

# %% [markdown]
# ### Características da Distribuição Normal
#
# **Simetria**: A curva é simétrica em torno da média, o que significa que a média, a mediana e a moda são iguais.
# Média (μ): O valor central da distribuição.
#
# **Desvio Padrão (σ)**: Indica a dispersão dos dados em relação à média. Na distribuição normal, aproximadamente 68% dos dados caem dentro de 1 desvio padrão da média, 95% dentro de 2 desvios padrão, e 99.7% dentro de 3 desvios padrão.
#
# **Curva em Sino**: A forma da curva da distribuição normal se assemelha a um sino, com a maioria dos valores concentrados em torno da média.

# %% [markdown]
# ### Min e Max

# %% [markdown]
# Os valores mínimo (min) e máximo (max) são os extremos de um conjunto de dados. Eles representam, respectivamente, o menor e o maior valor presente no conjunto.
#
# Min (mínimo): É o menor valor de um conjunto de dados.
#
# Max (máximo): É o maior valor de um conjunto de dados.
#
# Estes valores são frequentemente utilizados para descrever o intervalo ou amplitude dos dados, que é simplesmente a diferença entre o máximo e o mínimo

# %% [markdown]
# ### Z-Score

# %% [markdown]
# O Z-Score (ou escore z) é uma medida estatística que descreve a posição de um valor em relação à média de um conjunto de dados, em termos de desvios padrão. Ele indica quantos desvios padrão um determinado valor está acima ou abaixo da média.

# %% [markdown]
# ### Visualizando uma Distribuicao Normalizada

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Gerar dados simulados de uma distribuição normal
mu, sigma = 100, 15  # média e desvio padrão
dados = np.random.normal(mu, sigma, 1000)

# Criar um DataFrame
df = pd.DataFrame(dados, columns=['Valores'])

# Plotar o histograma
plt.figure(figsize=(10, 6))
plt.hist(df['Valores'], bins=30, color='lightblue', edgecolor='black', density=True)

# Plotar a curva da distribuição normal
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = np.exp(-((x - mu) ** 2) / (2 * sigma ** 2)) / (sigma * np.sqrt(2 * np.pi))
plt.plot(x, p, 'r', linewidth=2)

# Adicionar título e rótulos aos eixos
plt.title('Histograma da Distribuição Normal Simulada')
plt.xlabel('Valores')
plt.ylabel('Densidade')

# Exibir o gráfico
plt.show()

# %% [markdown]
# #### Explicação
#
# Gerar Dados: Usamos np.random.normal(mu, sigma, 1000) para gerar 1000 valores que seguem uma distribuição normal com média 𝜇 =100  e desvio padrão 𝜎 = 15.
#
# Histograma: O histograma mostra a distribuição dos dados gerados. O parâmetro density=True normaliza o histograma para que a área total seja igual a 1.
#
# Curva da Distribuição: A linha vermelha sobreposta no histograma representa a curva teórica da distribuição normal para os mesmos 𝜇 e 𝜎, o que ajuda a visualizar a conformidade dos dados simulados com a distribuição normal.
# Customização: Adicionamos título e rótulos para melhorar a legibilidade do gráfico.

# %% [markdown]
# ### Fórmula da Distribuição Normal
#
# A função de densidade de probabilidade para a distribuição normal é dada por:
#
# $$
# f(x) = \frac{1}{\sigma \sqrt{2\pi}} \exp\left(-\frac{(x - \mu)^2}{2\sigma^2}\right)
# $$
#
# Onde:
# - \( x \) é o valor da variável aleatória.
# - \( \mu \) é a média da distribuição.
# - \( \sigma \) é o desvio padrão.
# - \( \exp \) representa a função exponencial.
#
# Essa fórmula mostra como a probabilidade se distribui em torno da média \( \mu \) para uma variável que segue uma distribuição normal, sendo mais alta próximo à média e caindo conforme nos afastamos dela.
